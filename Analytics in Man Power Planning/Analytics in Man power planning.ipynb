# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'E:\DCS 5th SEMESTER\HR LAB\train.csv')
data
# Out:
#     sl_no                    Designation    stream specialisation  \
# 0       1              Software Engineer  Commerce         Mkt&HR
# 1       2                     Supervisor   Science        Mkt&Fin
# 2       3                       Operator      Arts        Mkt&Fin
# 3       4                        Fresher   Science         Mkt&HR
# 4       5                        Manager  Commerce        Mkt&Fin
# 5       6                    Team Leader   Science        Mkt&Fin
# 6       7                   Data Analyst  Commerce        Mkt&Fin
# 7       8               Buisness Analyst   Science        Mkt&Fin
# 8       9              Decision  Analyst  Commerce        Mkt&Fin
# 9      10                General Manager  Commerce        Mkt&Fin
# 10     11                      Developer  Commerce         Mkt&HR
# 11     12        Chief Executive Officer  Commerce        Mkt&Fin
# 12     13                       Director   Science         Mkt&HR
# 13     14             Senior Engineering  Commerce        Mkt&Fin
# 14     15                     Accountant  Commerce         Mkt&HR
# 15     16        Chief Financial Officer  Commerce        Mkt&Fin
# 16     17                Cloud Architect  Commerce        Mkt&Fin
# 17     18              Big data Engineer  Commerce        Mkt&Fin
# 18     19                Product Manager  Commerce         Mkt&HR
# 19     20                  Web Developer      Arts        Mkt&Fin
# 20     21             Computer Scientist  Commerce         Mkt&HR
# 21     22  Application Security Engineer  Commerce        Mkt&Fin
# 22     23         Chief Security Officer   Science         Mkt&HR
# 23     24           Computer Technicians   Science        Mkt&Fin
# 24     25                        Plumber   Science        Mkt&Fin
# 25     26         Maintenance Supervisor  Commerce        Mkt&Fin
# 26     27            Front end developer  Commerce        Mkt&Fin
# 27     28             Back end developer  Commerce         Mkt&HR
# 28     29           Full Stack Developer  Commerce        Mkt&Fin
# 29     30      Junior Software developer  Commerce        Mkt&Fin
# 30     31      Intern Software developer  Commerce         Mkt&HR
# 31     32            Procurement Manager   Science         Mkt&HR
# 32     33               IT infra Manager  Commerce         Mkt&HR
# 33     34                Project manager   Science        Mkt&Fin
# 34     35                Product Manager   Science         Mkt&HR
# 35     36                Content Manager  Commerce         Mkt&HR
# 36     37         Database Administrator  Commerce        Mkt&Fin
# 37     38         Entry Level Programmer   Science         Mkt&HR
# 38     39                   Test Analyst   Science         Mkt&HR
# 39     40                 Technical Lead   Science        Mkt&Fin
# 40     41                 Test Executive  Commerce        Mkt&Fin
# 41     42                System Engineer  Commerce         Mkt&HR
# 42     43              Senior Accountant   Science        Mkt&Fin
# 43     44             Technology Analyst  Commerce         Mkt&HR
# 44     45                Finance Manager  Commerce        Mkt&Fin
# 45     46                 Techno Manager   Science         Mkt&HR
#
#    interested_in  Aptitude_Score  coding_score  degree_percentage  \
# 0       Sci&Tech           67.00         91.00              58.00
# 1       Sci&Tech           79.33         78.33              77.48
# 2      Comm&Mgmt           65.00         68.00              64.00
# 3       Sci&Tech           56.00         52.00              52.00
# 4      Comm&Mgmt           85.80         73.60              73.30
# 5       Sci&Tech           55.00         49.80              67.25
# 6      Comm&Mgmt           46.00         49.20              79.00
# 7       Sci&Tech           82.00         64.00              66.00
# 8      Comm&Mgmt           73.00         79.00              72.00
# 9      Comm&Mgmt           58.00         70.00              61.00
# 10     Comm&Mgmt           58.00         61.00              60.00
# 11     Comm&Mgmt           69.60         68.40              78.30
# 12     Comm&Mgmt           47.00         55.00              65.00
# 13     Comm&Mgmt           77.00         87.00              59.00
# 14     Comm&Mgmt           62.00         47.00              50.00
# 15     Comm&Mgmt           65.00         75.00              69.00
# 16     Comm&Mgmt           63.00         66.20              65.60
# 17     Comm&Mgmt           55.00         67.00              64.00
# 18     Comm&Mgmt           63.00         66.00              64.00
# 19     Comm&Mgmt           60.00         67.00              70.00
# 20     Comm&Mgmt           62.00         65.00              66.00
# 21     Comm&Mgmt           79.00         76.00              85.00
# 22      Sci&Tech           69.80         60.80              72.23
# 23      Sci&Tech           77.40         60.00              64.74
# 24      Sci&Tech           76.50         97.70              78.86
# 25     Comm&Mgmt           52.58         54.60              50.20
# 26     Comm&Mgmt           71.00         79.00              66.00
# 27     Comm&Mgmt           63.00         67.00              66.00
# 28     Comm&Mgmt           76.76         76.50              67.50
# 29     Comm&Mgmt           62.00         67.00              58.00
# 30     Comm&Mgmt           64.00         73.50              73.00
# 31      Sci&Tech           67.00         53.00              65.00
# 32     Comm&Mgmt           61.00         81.00              66.40
# 33     Comm&Mgmt           87.00         65.00              81.00
# 34        Others           62.00         51.00              52.00
# 35     Comm&Mgmt           69.00         78.00              72.00
# 36     Comm&Mgmt           51.00         44.00              57.00
# 37      Sci&Tech           79.00         76.00              65.60
# 38     Comm&Mgmt           73.00         58.00              66.00
# 39      Sci&Tech           81.00         68.00              64.00
# 40     Comm&Mgmt           78.00         77.00              80.00
# 41     Comm&Mgmt           74.00         63.16              65.00
# 42        Others           49.00         39.00              65.00
# 43     Comm&Mgmt           87.00         87.00              68.00
# 44     Comm&Mgmt           77.00         73.00              81.00
# 45      Sci&Tech           76.00         64.00              72.00
#
#     etest_percentage  mba_percentage  Salary Expected  status
# 0              55.00           58.80            25000       1
# 1              86.50           66.28            23000       1
# 2              75.00           57.80            20000       1
# 3              66.00           59.43            20000       0
# 4              96.80           55.50            80000       1
# 5              55.00           51.58            70000       0
# 6              74.28           53.29            60000       0
# 7              67.00           62.14            60000       1
# 8              91.34           61.29            62000       1
# 9              54.00           52.21           770000       0
# 10             62.00           60.85            50000       1
# 11             60.00           63.70            66000       1
# 12             62.00           65.04            80000       0
# 13             68.00           68.63            50000       1
# 14             76.00           54.96            45000       0
# 15             72.00           64.66            63000       1
# 16             60.00           62.54            44000       1
# 17             60.00           67.28            61000       0
# 18             68.00           64.08            61000       0
# 19             50.48           77.89            61000       1
# 20             50.00           56.70            55000       1
# 21             95.00           69.06            42000       1
# 22             55.53           68.81            60000       1
# 23             92.00           63.62            56000       1
# 24             97.40           74.01            20000       1
# 25             76.00           65.33            54000       0
# 26             94.00           57.55            54000       1
# 27             68.00           57.69            55000       1
# 28             73.35           64.15            60000       1
# 29             77.00           51.29            30000       0
# 30             52.00           56.70            15000       1
# 31             64.00           58.32            40000       0
# 32             50.89           62.21            60000       1
# 33             88.00           72.78            73000       1
# 34             68.44           62.77            76000       0
# 35             71.00           62.74            56000       1
# 36             64.00           51.45            63000       0
# 37             58.00           55.47            25000       1
# 38             53.70           56.86            50000       1
# 39             93.00           62.56            56000       1
# 40             60.00           66.72            55000       1
# 41             65.00           69.76            45000       0
# 42             63.00           51.21            60000       0
# 43             95.00           62.90            67000       1
# 44             89.00           69.70            72000       1
# 45             58.00           66.53            90000       0

# %%
data.head()
# Out:
#    sl_no        Designation    stream specialisation interested_in  \
# 0      1  Software Engineer  Commerce         Mkt&HR      Sci&Tech
# 1      2         Supervisor   Science        Mkt&Fin      Sci&Tech
# 2      3           Operator      Arts        Mkt&Fin     Comm&Mgmt
# 3      4            Fresher   Science         Mkt&HR      Sci&Tech
# 4      5            Manager  Commerce        Mkt&Fin     Comm&Mgmt
#
#    Aptitude_Score  coding_score  degree_percentage  etest_percentage  \
# 0           67.00         91.00              58.00              55.0
# 1           79.33         78.33              77.48              86.5
# 2           65.00         68.00              64.00              75.0
# 3           56.00         52.00              52.00              66.0
# 4           85.80         73.60              73.30              96.8
#
#    mba_percentage  Salary Expected  status
# 0           58.80            25000       1
# 1           66.28            23000       1
# 2           57.80            20000       1
# 3           59.43            20000       0
# 4           55.50            80000       1

# %%
data.describe()
# Out:
#            sl_no  Aptitude_Score  coding_score  degree_percentage  \
# count  46.000000       46.000000     46.000000          46.000000
# mean   23.500000       67.647174     67.147609          67.010000
# std    13.422618       10.848867     12.604357           8.297467
# min     1.000000       46.000000     39.000000          50.000000
# 25%    12.250000       61.250000     60.200000          64.000000
# 50%    23.500000       67.000000     67.000000          66.000000
# 75%    34.750000       76.940000     76.000000          72.000000
# max    46.000000       87.000000     97.700000          85.000000
#
#        etest_percentage  mba_percentage  Salary Expected     status
# count         46.000000       46.000000        46.000000  46.000000
# mean          70.232826       61.844348     68695.652174   0.652174
# std           14.568932        6.382259    107141.623733   0.481543
# min           50.000000       51.210000     15000.000000   0.000000
# 25%           60.000000       57.032500     45000.000000   0.000000
# 50%           67.500000       62.550000     56000.000000   1.000000
# 75%           76.750000       66.042500     62750.000000   1.000000
# max           97.400000       77.890000    770000.000000   1.000000

# %%
data.isnull().sum()
# Out:
# sl_no                0
# Designation          0
# stream               0
# specialisation       0
# interested_in        0
# Aptitude_Score       0
# coding_score         0
# degree_percentage    0
# etest_percentage     0
# mba_percentage       0
# Salary Expected      0
# status               0
# dtype: int64

# %%
data.shape
# Out:
# (46, 12)

# %%
data.columns
# Out:
# Index(['sl_no', 'Designation', 'stream', 'specialisation', 'interested_in',
#        'Aptitude_Score', 'coding_score', 'degree_percentage',
#        'etest_percentage', 'mba_percentage', 'Salary Expected', 'status'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sl_no              46 non-null     int64
#  1   Designation        46 non-null     object
#  2   stream             46 non-null     object
#  3   specialisation     46 non-null     object
#  4   interested_in      46 non-null     object
#  5   Aptitude_Score     46 non-null     float64
#  6   coding_score       46 non-null     float64
#  7   degree_percentage  46 non-null     float64
#  8   etest_percentage   46 non-null     float64
#  9   mba_percentage     46 non-null     float64
#  10  Salary Expected    46 non-null     int64
#  11  status             46 non-null     int64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 4.4+ KB

# %%
data.duplicated().any()
# Out:
# False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sl_no              46 non-null     int64
#  1   Designation        46 non-null     object
#  2   stream             46 non-null     object
#  3   specialisation     46 non-null     object
#  4   interested_in      46 non-null     object
#  5   Aptitude_Score     46 non-null     float64
#  6   coding_score       46 non-null     float64
#  7   degree_percentage  46 non-null     float64
#  8   etest_percentage   46 non-null     float64
#  9   mba_percentage     46 non-null     float64
#  10  Salary Expected    46 non-null     int64
#  11  status             46 non-null     int64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 4.4+ KB

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics

# %%
# load dataset
data = pd.read_csv("train.csv")

# %%
data.head()
# Out:
#    sl_no        Designation    stream specialisation interested_in  \
# 0      1  Software Engineer  Commerce         Mkt&HR      Sci&Tech
# 1      2         Supervisor   Science        Mkt&Fin      Sci&Tech
# 2      3           Operator      Arts        Mkt&Fin     Comm&Mgmt
# 3      4            Fresher   Science         Mkt&HR      Sci&Tech
# 4      5            Manager  Commerce        Mkt&Fin     Comm&Mgmt
#
#    Aptitude_Score  coding_score  degree_percentage  etest_percentage  \
# 0           67.00         91.00              58.00              55.0
# 1           79.33         78.33              77.48              86.5
# 2           65.00         68.00              64.00              75.0
# 3           56.00         52.00              52.00              66.0
# 4           85.80         73.60              73.30              96.8
#
#    mba_percentage  Salary Expected  status
# 0           58.80            25000       1
# 1           66.28            23000       1
# 2           57.80            20000       1
# 3           59.43            20000       0
# 4           55.50            80000       1

# %%
#Number of employess and their education status - Promotion
plt.figure(figsize=(6,6))
sns.barplot(x='degree_percentage',y='Aptitude_Score',hue='status',data=data)
plt.show()

# %%
sns.countplot(x='interested_in',data=data,palette='Greens_d')
# Out:
# <AxesSubplot: xlabel='interested_in', ylabel='count'>

# %%
data.corr()
# Out:
# C:\Users\MITHRAA\AppData\Local\Temp\ipykernel_17080\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                       sl_no  Aptitude_Score  coding_score  degree_percentage  \
# sl_no              1.000000        0.238502     -0.035502           0.111177
# Aptitude_Score     0.238502        1.000000      0.592362           0.452029
# coding_score      -0.035502        0.592362      1.000000           0.386618
# degree_percentage  0.111177        0.452029      0.386618           1.000000
# etest_percentage   0.024699        0.513118      0.292103           0.270929
# mba_percentage     0.138815        0.401045      0.396476           0.395400
# Salary Expected   -0.113250       -0.131696     -0.008829          -0.084979
# status            -0.024066        0.624337      0.668554           0.476692
#
#                    etest_percentage  mba_percentage  Salary Expected    status
# sl_no                      0.024699        0.138815        -0.113250 -0.024066
# Aptitude_Score             0.513118        0.401045        -0.131696  0.624337
# coding_score               0.292103        0.396476        -0.008829  0.668554
# degree_percentage          0.270929        0.395400        -0.084979  0.476692
# etest_percentage           1.000000        0.189442        -0.161775  0.231248
# mba_percentage             0.189442        1.000000        -0.201196  0.325232
# Salary Expected           -0.161775       -0.201196         1.000000 -0.226502
# status                     0.231248        0.325232        -0.226502  1.000000

# %%
plt.figure(figsize=(12,7))
sns.heatmap(data.corr(),annot=True,cmap='Blues')
plt.show()
# Out:
# C:\Users\MITHRAA\AppData\Local\Temp\ipykernel_17080\401207663.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,cmap='Blues')

# %%
#split dataset in features and target variable
feature_cols = ['etest_percentage','coding_score','degree_percentage',
       'Aptitude_Score', 'mba_percentage', 'Salary Expected']
X = data[feature_cols] # Features
y = data["status"] # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
# ### Decision Tree Model

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()
# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)
#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
#Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7142857142857143

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 10))
tree.plot_tree(clf, filled=True, rounded=True,feature_names = feature_cols,class_names = ['0','1'])
plt.show()

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 10))
tree.plot_tree(clf, filled=True, rounded=True)
plt.show()

# %% [markdown]
# ### Naive Bayes Model

# %%
#Naive-Bayes
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Making prediction
nb_pred=nb.predict(X_test)

# %%
#Model Evaluation
from sklearn.metrics import accuracy_score
print("Train Accuracy : ", nb.score(X_train, y_train)*100)
print("Test Accuracy : ", nb.score(X_test, y_test)*100)
print("Accuracy Score of Naive Bayes : ", accuracy_score(y_test, nb_pred)*100)
# Out:
# Train Accuracy :  81.25
# Test Accuracy :  100.0
# Accuracy Score of Naive Bayes :  100.0

# %% [markdown]
# ### Random Forest Model

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn import datasets

# %%
X, y = datasets.load_iris( return_X_y = True)
# Spliting arrays or matrices into random train and test subsets
from sklearn.model_selection import train_test_split
# i.e. 70 % training dataset and 30 % test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
from sklearn.ensemble import RandomForestClassifier
# Create a Random forest Classifier
clf = RandomForestClassifier(n_estimators = 100)
 
# Train the model using the training sets
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
clf = RandomForestClassifier(n_estimators = 100) 
 
# Training the model on the training dataset
# fit function is used to train the model using the training sets as parameters
clf.fit(X_train, y_train)
 
# performing predictions on the test dataset
y_pred = clf.predict(X_test)
 
# metrics are used to find accuracy or error
from sklearn import metrics 
print()
 
# using metrics module for accuracy calculation
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.9555555555555556

# %%
clf.predict([[58,70	,61,54]])
# Out:
# array([2])

# %%
d=data.iloc[:,5:11]
print(d)
# Out:
#     Aptitude_Score  coding_score  degree_percentage  etest_percentage  \
# 0            67.00         91.00              58.00             55.00
# 1            79.33         78.33              77.48             86.50
# 2            65.00         68.00              64.00             75.00
# 3            56.00         52.00              52.00             66.00
# 4            85.80         73.60              73.30             96.80
# 5            55.00         49.80              67.25             55.00
# 6            46.00         49.20              79.00             74.28
# 7            82.00         64.00              66.00             67.00
# 8            73.00         79.00              72.00             91.34
# 9            58.00         70.00              61.00             54.00
# 10           58.00         61.00              60.00             62.00
# 11           69.60         68.40              78.30             60.00
# 12           47.00         55.00              65.00             62.00
# 13           77.00         87.00              59.00             68.00
# 14           62.00         47.00              50.00             76.00
# 15           65.00         75.00              69.00             72.00
# 16           63.00         66.20              65.60             60.00
# 17           55.00         67.00              64.00             60.00
# 18           63.00         66.00              64.00             68.00
# 19           60.00         67.00              70.00             50.48
# 20           62.00         65.00              66.00             50.00
# 21           79.00         76.00              85.00             95.00
# 22           69.80         60.80              72.23             55.53
# 23           77.40         60.00              64.74             92.00
# 24           76.50         97.70              78.86             97.40
# 25           52.58         54.60              50.20             76.00
# 26           71.00         79.00              66.00             94.00
# 27           63.00         67.00              66.00             68.00
# 28           76.76         76.50              67.50             73.35
# 29           62.00         67.00              58.00             77.00
# 30           64.00         73.50              73.00             52.00
# 31           67.00         53.00              65.00             64.00
# 32           61.00         81.00              66.40             50.89
# 33           87.00         65.00              81.00             88.00
# 34           62.00         51.00              52.00             68.44
# 35           69.00         78.00              72.00             71.00
# 36           51.00         44.00              57.00             64.00
# 37           79.00         76.00              65.60             58.00
# 38           73.00         58.00              66.00             53.70
# 39           81.00         68.00              64.00             93.00
# 40           78.00         77.00              80.00             60.00
# 41           74.00         63.16              65.00             65.00
# 42           49.00         39.00              65.00             63.00
# 43           87.00         87.00              68.00             95.00
# 44           77.00         73.00              81.00             89.00
# 45           76.00         64.00              72.00             58.00
#
#     mba_percentage  Salary Expected
# 0            58.80            25000
# 1            66.28            23000
# 2            57.80            20000
# 3            59.43            20000
# 4            55.50            80000
# 5            51.58            70000
# 6            53.29            60000
# 7            62.14            60000
# 8            61.29            62000
# 9            52.21           770000
# 10           60.85            50000
# 11           63.70            66000
# 12           65.04            80000
# 13           68.63            50000
# 14           54.96            45000
# 15           64.66            63000
# 16           62.54            44000
# 17           67.28            61000
# 18           64.08            61000
# 19           77.89            61000
# 20           56.70            55000
# 21           69.06            42000
# 22           68.81            60000
# 23           63.62            56000
# 24           74.01            20000
# 25           65.33            54000
# 26           57.55            54000
# 27           57.69            55000
# 28           64.15            60000
# 29           51.29            30000
# 30           56.70            15000
# 31           58.32            40000
# 32           62.21            60000
# 33           72.78            73000
# 34           62.77            76000
# 35           62.74            56000
# 36           51.45            63000
# 37           55.47            25000
# 38           56.86            50000
# 39           62.56            56000
# 40           66.72            55000
# 41           69.76            45000
# 42           51.21            60000
# 43           62.90            67000
# 44           69.70            72000
# 45           66.53            90000
# 79.33       1
# 78.33       1
# 77.48       1
# 86.50       1
# 66.28       1
# 23000.00    1
# Name: 1, dtype: int64
# 0.8055555555555556
# 0.7
# c:\Users\MITHRAA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
i=1
S=d.iloc[i,:].value_counts()
print(S)
orders=[]
# Out:
# 79.33       1
# 78.33       1
# 77.48       1
# 86.50       1
# 66.28       1
# 23000.00    1
# Name: 1, dtype: int64

# %%
for i in range(1,16):
  orders.append(d.iloc[i,:].value_counts("Present"))
  #print(orders)
orders[1].plot.bar()
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
data['Designation']=LE.fit_transform(data['Designation'])
data['stream']=LE.fit_transform(data['stream'])
data['specialisation']=LE.fit_transform(data['specialisation'])
data['interested_in']=LE.fit_transform(data['interested_in'])
#print(data)

# %% [markdown]
# ### K-Nearest Neighbour

# %%
data.head(5)
data.isnull().sum()
X=data[['Designation','stream','specialisation','interested_in','Aptitude_Score','coding_score','degree_percentage','etest_percentage','mba_percentage','Salary Expected']]
Y=data['status']
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20,random_state=2)
knn3 = KNeighborsClassifier(n_neighbors=2)
model3=knn3.fit(x_train, y_train)
y_pred=model3.predict(x_test)
y_pred
y_test.to_numpy()
print(model3.score(x_train, y_train))
print(model3.score(x_test, y_test))
# Out:
# 0.8055555555555556
# 0.7

# %%
from sklearn import metrics
metrics.confusion_matrix(y_test, y_pred)
knn4 = KNeighborsClassifier(n_neighbors=2)
model4=knn4.fit(x_train, y_train)
y_pred=model4.predict(x_test)
y_pred
# Out:
# array([1, 0, 0, 0, 1, 0, 0, 1, 1, 1], dtype=int64)

# %%
y_test.to_numpy()
model4.score(x_train,y_train)
model4.score(x_test,y_test)
neighbors = np.arange(1, 1)
train_accuracy = np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))

# %%
for i, k in enumerate(neighbors):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    train_accuracy[i] = knn.score(x_train, y_train)
    test_accuracy[i] = knn.score(x_test, y_test)

# %%
model4.predict([[36, 0, 0, 2, 12,20, 11, 21, 10, 1]])
# Out:
# c:\Users\MITHRAA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
